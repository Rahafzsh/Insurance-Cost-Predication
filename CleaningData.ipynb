# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("Dataset//HealthCare_Claims.xlsx")

# %%
df
# Out:
#        encounter_id  patient_id                         name Gender  \
# 0             65122    10648150           نصر الدّين المهيدب    NaN
# 1             34890    10193568                  جودي الحجار    NaN
# 2             51650    10477631                نشأت آل صفوان    NaN
# 3             85053    10933366               عذب آل بن لافي    NaN
# 4             26310    10090844                   سجى الشايع    NaN
# ...             ...         ...                          ...    ...
# 12679         23176    10051015                 خميس المهيدب    NaN
# 12680         87583    10895722             زيدان آل بن ظافر    NaN
# 12681         58828    10566676                    هناء فصيل    NaN
# 12682         57853    10494171  دانة آل محمد بن علي بن جماز    NaN
# 12683         23706    10060613                روبين آل عواض    NaN
#
#        doctor_id             doctor_name  hospital_id          hospital_name  \
# ...
