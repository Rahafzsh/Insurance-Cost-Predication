# %%
import polars as pl
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
df = pl.read_excel("Dataset//HealthCare_Claims.xlsx")
# Out:
# Could not determine dtype for column 3, falling back to string
# Could not determine dtype for column 17, falling back to string

# %%
df
# Out:
# shape: (12_684, 18)
# ┌────────────┬────────────┬───────────┬────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ encounter_ ┆ patient_id ┆ name      ┆ Gender ┆ … ┆ admission ┆ medicatio ┆ test_resu ┆ Length_of │
# │ id         ┆ ---        ┆ ---       ┆ ---    ┆   ┆ _type     ┆ n         ┆ ltS       ┆ _Stay     │
# │ ---        ┆ i64        ┆ str       ┆ str    ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │ i64        ┆            ┆           ┆        ┆   ┆ str       ┆ str       ┆ str       ┆ str       │
# ╞════════════╪════════════╪═══════════╪════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 65122      ┆ 10648150   ┆ نصر الدّين ┆ null   ┆ … ┆ Urgent    ┆ Paracetam ┆ Inconclus ┆ null      │
# │            ┆            ┆ المهيدب   ┆        ┆   ┆           ┆ ol        ┆ ive       ┆           │
# │ 34890      ┆ 10193568   ┆ جودي      ┆ null   ┆ … ┆ Emergency ┆ Paracetam ┆ Normal    ┆ null      │
# ...
